# %%
import pandas as pd

# %%
df = pd.read_excel('miharu_data/UCrCuHGz8MkF_ii6JKqbacZA/info/data_UCrCuHGz8MkF_ii6JKqbacZA.xlsx', index_col=None)

# %%
df
# Out:
#    publishedAt                                              title  \
# 0          NaN     【ZOZOマリンスタジアム】食品販売から千葉ロッテマリーンズのスタジアムビジネスに切り込む！
# 1          NaN              日本最先端のスタジアムビジネスをジャイアンツの本拠地、東京ドームから学ぶ！
# 2          NaN  【強いのは野球だけじゃない！】明治神宮球場のスタジアムビジネスをチェック！商品設定が秀逸だった！？
# 3          NaN         【Y.S.C.C.横浜】サッカーJ3のスポーツ・スタジアムビジネスをデータで観てみた
# 4          NaN    【Jリーグ】セレッソ大阪は一日あたり何円儲かってるのかを試算してスタジアムビジネスをチェック！
# 5          NaN                  【流れ工程分析】オリックスバファローズのスタジアムビジネスを調査！
# 6          NaN                  未来のスポーツスタジアム経営はどうなる？理系目線で分析してみたい！
#
#                                          description           id  \
# 0  ご視聴ありがとうがとうございます！\n大学の理工学部で経営工学を学びながら、トップスポーツビ...  Zp66jB4UXSo
# 1  ご視聴ありがとうがとうございます！\n大学の理工学部で経営工学を学びながら、トップスポーツビ...  OmyZ_IFtBAA
# 2  ご視聴ありがとうがとうございます！\n大学の理工学部で経営工学を学びながら、トップスポーツビ...  AazCWPLUSt4
# 3  ご視聴ありがとうがとうございます！\n大学の理工学部で経営工学を学びながら、トップスポーツビ...  nH6sOUiRzZ8
# 4  【訂正】\nベイスターズのクラフトビールの計算のところで引用のミスがありました。正しくは以下...  jvw7rkeM8zY
# 5  ご視聴ありがとうがとうございます！\n大学の理工学部で経営工学を学びながら、トップスポーツビ...  3XOlHxOy9k0
# 6  【訂正】\nクラフトビールの計算ですが、計算ミスが見つかりました。大変失礼しました。\n正し...  bDz9QC-dKUg
#
#                                       thumbnail_url  categoryId  \
# 0  https://i.ytimg.com/vi/Zp66jB4UXSo/hqdefault.jpg          22
# 1  https://i.ytimg.com/vi/OmyZ_IFtBAA/hqdefault.jpg          22
# 2  https://i.ytimg.com/vi/AazCWPLUSt4/hqdefault.jpg          22
# 3  https://i.ytimg.com/vi/nH6sOUiRzZ8/hqdefault.jpg          22
# 4  https://i.ytimg.com/vi/jvw7rkeM8zY/hqdefault.jpg          22
# 5  https://i.ytimg.com/vi/3XOlHxOy9k0/hqdefault.jpg          22
# 6  https://i.ytimg.com/vi/bDz9QC-dKUg/hqdefault.jpg          22
#
#   liveBroadcastContent  duration  viewCount  likeCount  favoriteCount  \
# 0                 none  00:12:23        223          5              0
# 1                 none  00:09:04        206          6              0
# 2                 none  00:07:22        120          2              0
# 3                 none  00:08:06        451          8              0
# 4                 none  00:05:55       1162         13              0
# 5                 none  00:07:06        227         10              0
# 6                 none  00:03:07        461         22              0
#
#    commentCount                                          embedHtml
# 0             0  <iframe width="480" height="270" src="//www.yo...
# 1             2  <iframe width="480" height="270" src="//www.yo...
# 2             0  <iframe width="480" height="270" src="//www.yo...
# 3             6  <iframe width="480" height="270" src="//www.yo...
# 4            10  <iframe width="480" height="270" src="//www.yo...
# 5             0  <iframe width="480" height="270" src="//www.yo...
# 6             2  <iframe width="480" height="270" src="//www.yo...

# %%
Video_ids = list(df['id'])

# %%
# Out:
# ['Zp66jB4UXSo',
#  'OmyZ_IFtBAA',
#  'AazCWPLUSt4',
#  'nH6sOUiRzZ8',
#  'jvw7rkeM8zY',
#  '3XOlHxOy9k0',
#  'bDz9QC-dKUg']
